# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np

# %%
# built in mathematical funtion 
# sigmoid

def sigmoid(array):
    return(1/ 1 + np.exp(-(array)))

a = np.arange(100)

sigmoid(a)

# %%
# loss funtion
# linear regreation -> mean square error

# %%
actual = np.random.randint(1,50,25)
predicted =  np.random.randint(1,50,25)

# %%
actual

# %%
predicted

# %%
def mse(actual,predicted):
   return  np.mean((actual -  predicted )**2)

mse(actual ,predicted)

# %%
# working with missing values ->np.nan
a = np.array([1,2,3,4,5,np.nan,6])
a

# %%
a[~np.isnan(a)]

# %%
# sorting
a = np.random.randint(1,100,15)
a

# %%
b = np.random.randint(1,100,24).reshape(6,4)
b

# %%
np.sort(a)[::-1]  
# if required in increasing order

# %%
np.sort(b,axis=0)

# %%
# np.append =  appends values along the mentioned axis at the end of the array
np.append(a,200)

# %%
b

# %%
np.append(b,np.ones((b.shape[0],1)),axis =1)

# %%
# np.concatenate =  function concatinate a sequence of arrays along an existing axis
c = np.arange(6).reshape(2,3)
d = np.arange(6,12).reshape(2,3)

print(c)
print(d)

# %%
np.concatenate((c,d),axis=0)

# %%
np.concatenate((c,d),axis = 1)

# %%
np.unique(c)
# it  is widely use for separating out unique values

# %%
# expand dims
# with the help of numpy.expand_dims() method we can get the expand diamentionsof arrys
a.shape

# %%
np.expand_dims(a,axis =0).shape

# %%
np.expand_dims(a,axis =1)

# %%
# np.wher e it returns the indicies of elements in an input 
# array where the given codn is satisfied
a

# %%
np.where(a>50)

# %%
np.where(a>50,0,a)

# %%
np.where(a%2 == 0, 0,a)

# %%
# np.argmax returns indicies of the max element of the array in a particular axis
a

# %%
np.argmax(a)

# %%
np.argmax(b, axis = 0)

# %%
b

# %%
np.argmax(b, axis = 1)

# %%
# np.argmin 
np.argmin(a)

# %%
# np.cumsum  funtion is used to compute the cumulative sum of the elements over a given axis
a

# %%
np.cumsum(a)

# %%
b

# %%
np.cumsum(b,axis=0)

# %%
# np.percentile use to compute the nth percentile of the given data (array elements )
# along the specified azis
a

# %%
np.percentile(a,50)

# %%
np.median(a)

# %%
# np.histogram
a

# %%
np.histogram(a,bins =[0,50,100])

# %%
# np.corrcoef return pearson product moment correlation coefficients
salary = np.array([20000,400000,25000,65000,230000])
experience =  np.array([1,3,2,4,2])

np.corrcoef(salary,experience)
